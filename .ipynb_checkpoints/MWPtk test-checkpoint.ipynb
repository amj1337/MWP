# %%
import argparse
import sys
import os

# %%
from mwptoolkit.quick_start import run_toolkit

sys.path.insert(0, os.path.abspath(os.path.join(os.getcwd(), ".")))

if __name__ == '__main__':
    parser = argparse.ArgumentParser()
    parser.add_argument('--model', '-m', type=str, default='GTS', help='name of models')
    parser.add_argument('--dataset', '-d', type=str, default='math23k', help='name of datasets')
    parser.add_argument('--task_type', '-t', type=str, default='single_equation', help='name of tasks')

    args, _ = parser.parse_known_args()
    config_dict = {}

    #config_file_list = args.config_files.strip().split(' ') if args.config_files else None
    #run_toolkit()
    run_toolkit(args.model, args.dataset, args.task_type, config_dict)
# Out:
# ---------------------------------------------------------------------------
# InvalidVersion                            Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from mwptoolkit.quick_start import run_toolkit
#       3 sys.path.insert(0, os.path.abspath(os.path.join(os.getcwd(), ".")))
#       5 if __name__ == '__main__':
#
# File ~\anaconda3\envs\proj2\lib\site-packages\mwptoolkit\__init__.py:4
#       2 from __future__ import print_function
#       3 from __future__ import division
# ----> 4 from mwptoolkit import config,data,evaluate,loss,model,module,trainer,utils,hyper_search,quick_start
#
# File ~\anaconda3\envs\proj2\lib\site-packages\mwptoolkit\config\__init__.py:4
#       2 from __future__ import print_function
#       3 from __future__ import division
# ----> 4 from mwptoolkit.config import configuration
#       5 from mwptoolkit.config.configuration import Config
#
# File ~\anaconda3\envs\proj2\lib\site-packages\mwptoolkit\config\configuration.py:18
#      14 from enum import Enum
#      16 import torch
# ---> 18 from mwptoolkit.utils.utils import read_json_data, get_model, write_json_data
#      21 class Config(object):
#      22     """The class for loading pre-defined parameters.
#      23
#      24     Config will load the parameters from internal config file, dataset config file, model config file, config dictionary and cmd line.
#    (...)
#      43
#      44     """
#
# File ~\anaconda3\envs\proj2\lib\site-packages\mwptoolkit\utils\__init__.py:5
#       2 from __future__ import print_function
#       3 from __future__ import division
# ----> 5 from mwptoolkit.utils import data_structure,enum_type,logger,utils,preprocess_tool
#
# File ~\anaconda3\envs\proj2\lib\site-packages\mwptoolkit\utils\preprocess_tool\__init__.py:5
#       2 from __future__ import print_function
#       3 from __future__ import division
# ----> 5 from mwptoolkit.utils.preprocess_tool import dataset_operator,equation_operator,number_operator,number_transfer,sentence_operator
#
# File ~\anaconda3\envs\proj2\lib\site-packages\mwptoolkit\utils\preprocess_tool\dataset_operator.py:5
#       3 from mwptoolkit.utils.utils import str2float
#       4 from mwptoolkit.utils.enum_type import EPT
# ----> 5 from mwptoolkit.utils.preprocess_tool.sentence_operator import find_ept_numbers_in_text
#       6 from mwptoolkit.utils.preprocess_tool.number_operator import constant_number
#       7 from mwptoolkit.utils.preprocess_tool.equation_operator import orig_infix_to_postfix,infix_to_postfix
#
# File ~\anaconda3\envs\proj2\lib\site-packages\mwptoolkit\utils\preprocess_tool\sentence_operator.py:4
#       1 import re
#       3 import nltk
# ----> 4 import stanza
#       6 from mwptoolkit.utils.data_structure import DependencyTree
#       7 from mwptoolkit.utils.utils import write_json_data,read_json_data
#
# File ~\anaconda3\envs\proj2\lib\site-packages\stanza\__init__.py:1
# ----> 1 from stanza.pipeline.core import DownloadMethod, Pipeline
#       2 from stanza.pipeline.multilingual import MultilingualPipeline
#       3 from stanza.models.common.doc import Document
#
# File ~\anaconda3\envs\proj2\lib\site-packages\stanza\pipeline\core.py:29
#      27 from stanza.pipeline.constituency_processor import ConstituencyProcessor
#      28 from stanza.pipeline.coref_processor import CorefProcessor
# ---> 29 from stanza.pipeline.depparse_processor import DepparseProcessor
#      30 from stanza.pipeline.sentiment_processor import SentimentProcessor
#      31 from stanza.pipeline.ner_processor import NERProcessor
#
# File ~\anaconda3\envs\proj2\lib\site-packages\stanza\pipeline\depparse_processor.py:11
#       9 from stanza.models.common.vocab import VOCAB_PREFIX
#      10 from stanza.models.depparse.data import DataLoader
# ---> 11 from stanza.models.depparse.trainer import Trainer
#      12 from stanza.pipeline._constants import *
#      13 from stanza.pipeline.processor import UDProcessor, register_processor
#
# File ~\anaconda3\envs\proj2\lib\site-packages\stanza\models\depparse\trainer.py:12
#       9 from torch import nn
#      11 try:
# ---> 12     import transformers
#      13 except ImportError:
#      14     pass
#
# File ~\anaconda3\envs\proj2\lib\site-packages\transformers\__init__.py:43
#      40 from typing import TYPE_CHECKING
#      42 # Check the dependencies satisfy the minimal versions required.
# ---> 43 from . import dependency_versions_check
#      44 from .file_utils import (
#      45     _BaseLazyModule,
#      46     is_flax_available,
#    (...)
#      50     is_torch_available,
#      51 )
#      52 from .utils import logging
#
# File ~\anaconda3\envs\proj2\lib\site-packages\transformers\dependency_versions_check.py:41
#      38         if not is_tokenizers_available():
#      39             continue  # not required, check version only if installed
# ---> 41     require_version_core(deps[pkg])
#      42 else:
#      43     raise ValueError(f"can't find {pkg} in {deps.keys()}, check dependency_versions_table.py")
#
# File ~\anaconda3\envs\proj2\lib\site-packages\transformers\utils\versions.py:94, in require_version_core(requirement)
#      92 """ require_version wrapper which emits a core-specific hint on failure """
#      93 hint = "Try: pip install transformers -U or pip install -e '.[dev]' if you're working with git master"
# ---> 94 return require_version(requirement, hint)
#
# File ~\anaconda3\envs\proj2\lib\site-packages\transformers\utils\versions.py:85, in require_version(requirement, hint)
#      82     raise pkg_resources.DistributionNotFound(requirement, ["this application", hint])
#      84 # check that the right version is installed if version number was provided
# ---> 85 if want_ver is not None and not ops[op](version.parse(got_ver), version.parse(want_ver)):
#      86     raise pkg_resources.VersionConflict(
#      87         f"{requirement} is required for a normal functioning of this module, but found {pkg}=={got_ver}.{hint}"
#      88     )
#
# File ~\anaconda3\envs\proj2\lib\site-packages\packaging\version.py:52, in parse(version)
#      43 def parse(version: str) -> "Version":
#      44     """Parse the given version string.
#      45
#      46     >>> parse('1.0.dev1')
#    (...)
#      50     :raises InvalidVersion: When the version string is not a valid version.
#      51     """
# ---> 52     return Version(version)
#
# File ~\anaconda3\envs\proj2\lib\site-packages\packaging\version.py:197, in Version.__init__(self, version)
#     195 match = self._regex.search(version)
#     196 if not match:
# --> 197     raise InvalidVersion(f"Invalid version: '{version}'")
#     199 # Store the parsed out pieces of the version
#     200 self._version = _Version(
#     201     epoch=int(match.group("epoch")) if match.group("epoch") else 0,
#     202     release=tuple(int(i) for i in match.group("release").split(".")),
#    (...)
#     208     local=_parse_local_version(match.group("local")),
#     209 )
#
# InvalidVersion: Invalid version: '0.10.1,<0.11'
